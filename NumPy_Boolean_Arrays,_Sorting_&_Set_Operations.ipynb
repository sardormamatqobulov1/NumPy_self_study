# %% [markdown]
# <a href="https://colab.research.google.com/github/sardormamatqobulov1/NumPy_self_study/blob/main/NumPy_Boolean_Arrays%2C_Sorting_%26_Set_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Methods for Boolean Arrays

# %%
import numpy as np

rng = np.random.default_rng()

# %%
arr = rng.standard_normal(100)

# %%
(arr > 0).sum() #Number of positive values
# Out:
# np.int64(44)

# %%
(arr <= 0).sum() #Number of non-positive values
# Out:
# np.int64(56)

# %%
bools = np.array([False, False, True, False])

# %%
bools.any()
# Out:
# np.True_

# %%
bools.all()
# Out:
# np.False_

# %%
#Sorting
arr = rng.standard_normal(6)
arr
# Out:
# array([-1.7224988 , -2.62850056, -0.69039637,  0.87883091,  0.17166166,
#         1.16053855])

# %%
arr.sort()

# %%
arr
# Out:
# array([-2.62850056, -1.7224988 , -0.69039637,  0.17166166,  0.87883091,
#         1.16053855])

# %%
arr = rng.standard_normal((5,3))

# %%
arr
# Out:
# array([[-0.18195577, -0.711173  ,  0.93694388],
#        [-1.2444732 ,  0.52619378, -0.82161587],
#        [-0.74394916, -0.32298337, -0.69418521],
#        [ 0.56039555,  0.02799477, -0.04964215],
#        [-0.65736809,  1.40802942, -1.53785745]])

# %%
arr.sort(axis=0)

# %%
arr
# Out:
# array([[-1.2444732 , -0.711173  , -1.53785745],
#        [-0.74394916, -0.32298337, -0.82161587],
#        [-0.65736809,  0.02799477, -0.69418521],
#        [-0.18195577,  0.52619378, -0.04964215],
#        [ 0.56039555,  1.40802942,  0.93694388]])

# %%
arr.sort(axis=1)

# %%
arr
# Out:
# array([[-1.53785745, -1.2444732 , -0.711173  ],
#        [-0.82161587, -0.74394916, -0.32298337],
#        [-0.69418521, -0.65736809,  0.02799477],
#        [-0.18195577, -0.04964215,  0.52619378],
#        [ 0.56039555,  0.93694388,  1.40802942]])

# %%
arr2 = np.array([5,-10,7,1,0,-3])

# %%
sorted_arr2 = np.sort(arr2)

# %%
sorted_arr2
# Out:
# array([-10,  -3,   0,   1,   5,   7])

# %% [markdown]
# ##Unique and Other Set Logic

# %%
names = np.array(["Bob", "Will", "joe", "Bob","Will", "Joe", "Joe"])

# %%
np.unique(names)
# Out:
# array(['Bob', 'Joe', 'Will', 'joe'], dtype='<U4')

# %%
ints = np.array([3,3,3,2,2,1,1,4,4])

# %%
np.unique(ints)
# Out:
# array([1, 2, 3, 4])

# %%
sorted(set(names))
# Out:
# [np.str_('Bob'), np.str_('Joe'), np.str_('Will'), np.str_('joe')]

# %%
values = np.array([6,0,0,3,2,5,6])

# %%
np.in1d(values, [2,3,6])
# Out:
# /tmp/ipython-input-1269275309.py:1: DeprecationWarning: `in1d` is deprecated. Use `np.isin` instead.
#   np.in1d(values, [2,3,6])
# array([ True, False, False,  True,  True, False,  True])
