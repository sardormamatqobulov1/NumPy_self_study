# %% [markdown]
# <a href="https://colab.research.google.com/github/sardormamatqobulov1/NumPy_self_study/blob/main/Linear_Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.array([[1.,2.,3.], [4.,5.,6.]])

# %%
y = np.array([[6., 23.], [-1,7], [8,9]])

# %%
x
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
y
# Out:
# array([[ 6., 23.],
#        [-1.,  7.],
#        [ 8.,  9.]])

# %%
x.dot(y)
# Out:
# array([[ 28.,  64.],
#        [ 67., 181.]])

# %%
np.dot(x, y)
# Out:
# array([[ 28.,  64.],
#        [ 67., 181.]])

# %%
x @ np.ones(3)
# Out:
# array([ 6., 15.])

# %%
from numpy.linalg import inv, qr

# %%
rng = np.random.default_rng()
X = rng.standard_normal((5,5))

# %%
mat = X.T @ X

# %%
inv(mat)
# Out:
# array([[ 0.34973472,  0.26512319, -0.08099318,  0.02009497,  0.09322411],
#        [ 0.26512319,  1.8059576 , -0.46579708, -0.38053403,  0.2557998 ],
#        [-0.08099318, -0.46579708,  0.46779847,  0.15779657, -0.40538274],
#        [ 0.02009497, -0.38053403,  0.15779657,  0.26567264, -0.04831995],
#        [ 0.09322411,  0.2557998 , -0.40538274, -0.04831995,  0.57787079]])

# %%
mat @ inv(mat)
# Out:
# array([[ 1.00000000e+00, -1.55740912e-17,  2.05480520e-17,
#         -1.40959091e-17,  3.56195077e-17],
#        [-1.50526951e-17,  1.00000000e+00,  3.33673826e-18,
#         -5.83577463e-17, -3.02358932e-18],
#        [-1.77995304e-17,  3.39421357e-16,  1.00000000e+00,
#         -1.07728529e-16, -8.73308133e-17],
#        [ 2.95789633e-17, -5.85573405e-17, -1.70643268e-16,
#          1.00000000e+00,  1.04362341e-16],
#        [-1.28344593e-16, -3.05396227e-16,  1.24936017e-17,
#         -5.48025433e-17,  1.00000000e+00]])

# %% [markdown]
# #Random Walks

# %%
import random
position = 0
walk = [position]
nsteps = 1000
for _ in range(nsteps):
  step = 1 if random.randint(0, 1) else -1
  position += step
  walk.append(position)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(walk[:100])

# %%
nsteps = 1000

# %%
rng = np.random.default_rng(seed=12345)

# %%
draws = rng.integers(0,2, size=nsteps)

# %%
steps = np.where(draws == 0,1,-2)

# %%
walk = steps.cumsum()

# %%
walk.min()
# Out:
# np.int64(-431)

# %%
walk.max()
# Out:
# np.int64(-1)

# %%
(np.abs(walk) >= 10).argmax()
# Out:
# np.int64(10)
