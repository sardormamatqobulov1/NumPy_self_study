# %% [markdown]
# <a href="https://colab.research.google.com/github/sardormamatqobulov1/NumPy_self_study/blob/main/Tic_Tac_Toe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
#Create the board
board = np.array([[' ']*3 for _ in range(3)])

# %%
#Funcrion to print the board
def print_board(board):
  for row in board:
    print(" | ".join(row))
  print()

# %%
#Function to check winner
def check_winner(board, player):
  for i in range(3):
    if all(board[i, :] == player) or all(board[:, i] == player):
      return True
    return False

# %%
player_turn = 'X'

# %%
4# Main game loop
for move in range(9):
    print_board(board)

    while True:
        try:
            row = int(input(f"Player {player_turn}, enter row (0-2): "))
            col = int(input(f"Player {player_turn}, enter column (0-2): "))
            if row not in [0,1,2] or col not in [0,1,2]:
                print("Please enter 0, 1, or 2.")
                continue
            if board[row, col] != ' ':
                print("This cell is already taken, choose another one.")
                continue
            break
        except ValueError:
            print("Please enter a number (0, 1, or 2).")

    board[row, col] = player_turn

    if check_winner(board, player_turn):
        print_board(board)
        print(f"Player {player_turn} wins! 🎉")
        break  # end game if someone wins

    # Switch turn
    player_turn = 'O' if player_turn == 'X' else 'X'

else:  # if loop ends without break, it's a draw
    print_board(board)
    print("It's a draw! 😐")
# Out:
#   |   |
#   |   |
#   |   |
#
# Player X, enter row (0-2): 2
# Player X, enter column (0-2): 1
#   |   |
#   |   |
#   | X |
#
# Player O, enter row (0-2): 1
# Player O, enter column (0-2): 2
#   |   |
#   |   | O
#   | X |
#
# Player X, enter row (0-2): 1
# Player X, enter column (0-2): 1
#   |   |
#   | X | O
#   | X |
#
# Player O, enter row (0-2): 0
# Player O, enter column (0-2): 1
#   | O |
#   | X | O
#   | X |
#
# Player X, enter row (0-2): 2
# Player X, enter column (0-2): 2
#   | O |
#   | X | O
#   | X | X
#
# Player O, enter row (0-2): 2
# Player O, enter column (0-2): 0
#   | O |
#   | X | O
# O | X | X
#
# Player X, enter row (0-2): 0
# Player X, enter column (0-2): 0
# X | O |
#   | X | O
# O | X | X
#
# Player O, enter row (0-2): 1
# Player O, enter column (0-2): 0
# X | O |
# O | X | O
# O | X | X
#
# Player X, enter row (0-2): 0
# Player X, enter column (0-2): 2
# X | O | X
# O | X | O
# O | X | X
#
# It's a draw! 😐
